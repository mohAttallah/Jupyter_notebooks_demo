# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv('/home/moh/Demo/Jupyter_notebooks_demo/csv/dataEntry.csv')
print(df)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
df['C'] = df['A'] * df['B']

# %%
df.to_csv('/home/moh/Demo/Jupyter_notebooks_demo/csv/result.csv', index=False)
print("save successfully");
# Out:
# save the data

# %%
plt.plot(df['C'], df['A'])

plt.title('Sample Chart')
plt.xlabel('C')
plt.ylabel('A')

plt.xticks(rotation=45)

plt.show()
